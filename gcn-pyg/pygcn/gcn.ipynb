# %%
# 使用PyG 简单实现 GCN

# %%
import torch
from torch_geometric.datasets import Planetoid, NELL
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

# %%
data=Planetoid(root='../data/CiteSeer',name='CiteSeer')
print(len(data))
# Out:
# 1

# %%
data=data[0]
print(data)
# Out:
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])

# %%
print(data.is_directed())
# Out:
# False

# %%
data.y  #表示节点的标签编号
# Out:
# tensor([3, 1, 5,  ..., 3, 1, 5])

# %%
data.train_mask #若为True 则表示该节点为训练节点
# Out:
# tensor([ True,  True,  True,  ..., False, False, False])

# %%
class GCN(torch.nn.Module):
    def __init__(self, num_node_features, num_classes):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(num_node_features, 32)
        self.conv2 = GCNConv(32, num_classes)
        self.norm = torch.nn.BatchNorm1d(32)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.norm(x)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)

        return x

# %%
def train(model,data,device):
    optimizer=torch.optim.Adam(model.parameters(),lr=0.01,weight_decay=1e-4)
    loss_fun=torch.nn.CrossEntropyLoss().to(device=device)
    model.train()

    for epoch in range(200):
        out=model(data)
        optimizer.zero_grad()
        loss=loss_fun(out[data.train_mask],data.y[data.train_mask])
        loss.backward()
        optimizer.step()

        print('Epoch {:03d} loss{: .4f}'.format(epoch,loss.item()))

# %%
def test(model,data):
    model.eval()
    _,pred=model(data).max(dim=1)
    correct=int(pred[data.test_mask].eq(data.y[data.test_mask]).sum().item())
    acc=correct/int(data.test_mask.sum())

    print('GCN Accuracy {:.4f}'.format(acc))

# %%
def load_data(name):
    if name=='NELL':
        print('../data/'+name+'/')
        dataset=NELL(root='../data/'+name+'/')
    else:
        dataset = Planetoid(root='../data/' + name + '/', name=name)
    
    _device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    data=dataset[0].to(_device)
    if name=='NELL':
        data.x=data.x.to_dense()
        num_node_features=dataset.x.shape[1]
    else:
        num_node_features=dataset.num_node_features
    
    return data,num_node_features,dataset.num_classes

# %%
def main():
    names = ['CiteSeer', 'Cora', 'PubMed']
    for name in names:
        print(name+'...')
        data,num_node_features,num_classes=load_data(name)
        print(data,num_node_features,num_classes)
        _device ='cuda'
        device = torch.device(_device)
        model=GCN(num_node_features,num_classes).to(device)
        train(model,data,device)
        test(model,data)

# %%
if __name__=='__main__':
    main()
# Out:
# CiteSeer...
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327]) 3703 6
# Epoch 000 loss 2.1580
# Epoch 001 loss 0.7630
# Epoch 002 loss 0.4595
# Epoch 003 loss 0.3265
# Epoch 004 loss 0.2377
# Epoch 005 loss 0.1595
# Epoch 006 loss 0.1622
# Epoch 007 loss 0.1186
# Epoch 008 loss 0.0941
# Epoch 009 loss 0.0794
# Epoch 010 loss 0.0832
# Epoch 011 loss 0.0538
# Epoch 012 loss 0.0645
# Epoch 013 loss 0.0596
# Epoch 014 loss 0.0360
# Epoch 015 loss 0.0656
# Epoch 016 loss 0.0402
# Epoch 017 loss 0.0387
# Epoch 120 loss 0.0024
# Epoch 121 loss 0.0043
# Epoch 122 loss 0.0039
# Epoch 123 loss 0.0017
# Epoch 124 loss 0.0025
# Epoch 125 loss 0.0070
# Epoch 126 loss 0.0018
# Epoch 127 loss 0.0014
# Epoch 128 loss 0.0013
# Epoch 129 loss 0.0009
# Epoch 130 loss 0.0014
# Epoch 131 loss 0.0024
# Epoch 132 loss 0.0043
# Epoch 133 loss 0.0023
# Epoch 134 loss 0.0009
# Epoch 135 loss 0.0013
# Epoch 136 loss 0.0010
# Epoch 137 loss 0.0031
# Epoch 138 loss 0.0007
# Epoch 139 loss 0.0010
# Epoch 140 loss 0.0022
# Epoch 141 loss 0.0047
# Epoch 142 loss 0.0073
# Epoch 143 loss 0.0028
# Epoch 144 loss 0.0018
# Epoch 145 loss 0.0014
# Epoch 146 loss 0.0040
# Epoch 147 loss 0.0012
# Epoch 148 loss 0.0018
# Epoch 149 loss 0.0007
# Epoch 150 loss 0.0037
# Epoch 151 loss 0.0017
# Epoch 152 loss 0.0012
# Epoch 153 loss 0.0010
# Epoch 154 loss 0.0026
# Epoch 155 loss 0.0043
# Epoch 156 loss 0.0011
# Epoch 157 loss 0.0037
# Epoch 158 loss 0.0015
# Epoch 159 loss 0.0029
# Epoch 160 loss 0.0047
# Epoch 161 loss 0.0037
# Epoch 162 loss 0.0063
# Epoch 163 loss 0.0049
# Epoch 164 loss 0.0012
# Epoch 165 loss 0.0056
# Epoch 166 loss 0.0022
# Epoch 167 loss 0.0042
# Epoch 168 loss 0.0064
# Epoch 169 loss 0.0029
# Epoch 170 loss 0.0029
# Epoch 171 loss 0.0025
# Epoch 172 loss 0.0039
# Epoch 173 loss 0.0026
# Epoch 174 loss 0.0338
# Epoch 175 loss 0.0013
# Epoch 176 loss 0.0010
# Epoch 177 loss 0.0019
# Epoch 178 loss 0.0046
# Epoch 179 loss 0.0044
# Epoch 180 loss 0.0009
# Epoch 181 loss 0.0069
# Epoch 182 loss 0.0014
# Epoch 183 loss 0.0038
# Epoch 184 loss 0.0036
# Epoch 185 loss 0.0011
# Epoch 186 loss 0.0119
# Epoch 187 loss 0.0151
# Epoch 188 loss 0.0021
# Epoch 189 loss 0.0014
# Epoch 190 loss 0.0029
# Epoch 191 loss 0.0030
# Epoch 192 loss 0.0041
# Epoch 193 loss 0.0068
# Epoch 194 loss 0.0028
# Epoch 195 loss 0.0026
# Epoch 196 loss 0.0026
# Epoch 197 loss 0.0110
# Epoch 198 loss 0.0031
# Epoch 199 loss 0.0032
# GCN Accuracy 0.5770
# Cora...
# Using existing file ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708]) 1433 7
# Data(x=[19717, 500], edge_index=[2, 88648], y=[19717], train_mask=[19717], val_mask=[19717], test_mask=[19717]) 500 3
# Epoch 000 loss 1.5879
# Epoch 001 loss 0.6403
# Epoch 002 loss 0.3616
# Epoch 003 loss 0.2355
# Epoch 004 loss 0.1331
# Epoch 005 loss 0.1140
# Epoch 006 loss 0.1013
# Epoch 007 loss 0.0907
# Epoch 008 loss 0.0644
# Epoch 009 loss 0.0528
# Epoch 010 loss 0.0467
# Epoch 011 loss 0.0523
# Epoch 012 loss 0.0317
# Epoch 013 loss 0.0260
# Epoch 014 loss 0.0240
# Epoch 015 loss 0.0207
# Epoch 016 loss 0.0206
# Epoch 017 loss 0.0221
# Epoch 018 loss 0.0151
# Epoch 019 loss 0.0129
# Epoch 020 loss 0.0093
# Epoch 021 loss 0.0107
# Epoch 022 loss 0.0144
# Epoch 023 loss 0.0079
# Epoch 024 loss 0.0044
# Epoch 025 loss 0.0058
# Epoch 026 loss 0.0075
# Epoch 027 loss 0.0040
# Epoch 028 loss 0.0073
# Epoch 029 loss 0.0048
# Epoch 030 loss 0.0036
# Epoch 031 loss 0.0033
# Epoch 032 loss 0.0026
# Epoch 033 loss 0.0030
# Epoch 034 loss 0.0031
# Epoch 035 loss 0.0073
# Epoch 036 loss 0.0020
# Epoch 037 loss 0.0030
# Epoch 038 loss 0.0008
# Epoch 039 loss 0.0021
# Epoch 040 loss 0.0047
# Epoch 041 loss 0.0020
# Epoch 042 loss 0.0022
# Epoch 043 loss 0.0033
# Epoch 044 loss 0.0021
# Epoch 045 loss 0.0011
# Epoch 046 loss 0.0015
# Epoch 047 loss 0.0031
# Epoch 048 loss 0.0035
# Epoch 049 loss 0.0013
# Epoch 050 loss 0.0127
# Epoch 051 loss 0.0013
# Epoch 052 loss 0.0019
# Epoch 053 loss 0.0012
# Epoch 054 loss 0.0012
# Epoch 055 loss 0.0015
# Epoch 056 loss 0.0006
# Epoch 057 loss 0.0022
# Epoch 058 loss 0.0008
# Epoch 059 loss 0.0009
# Epoch 060 loss 0.0014
# Epoch 061 loss 0.0007
# Epoch 062 loss 0.0008
# Epoch 063 loss 0.0008
# Epoch 064 loss 0.0012
# Epoch 065 loss 0.0006
# Epoch 066 loss 0.0009
# Epoch 067 loss 0.0016
# Epoch 068 loss 0.0009
# Epoch 069 loss 0.0022
# Epoch 070 loss 0.0016
# Epoch 071 loss 0.0006
# Epoch 072 loss 0.0008
# Epoch 073 loss 0.0012
# Epoch 074 loss 0.0006
# Epoch 075 loss 0.0009
# Epoch 076 loss 0.0015
# Epoch 077 loss 0.0038
# Epoch 078 loss 0.0013
# Epoch 079 loss 0.0005
# Epoch 080 loss 0.0005
# Epoch 081 loss 0.0011
# Epoch 082 loss 0.0014
# Epoch 083 loss 0.0004
# Epoch 084 loss 0.0014
# Epoch 085 loss 0.0007
# Epoch 086 loss 0.0006
# Epoch 087 loss 0.0011
# Epoch 088 loss 0.0010
# Epoch 089 loss 0.0009
# Epoch 090 loss 0.0047
# Epoch 091 loss 0.0021
# Epoch 092 loss 0.0118
# Epoch 093 loss 0.0012
# Epoch 094 loss 0.0003
# Epoch 095 loss 0.0007
# Epoch 096 loss 0.0003
# Epoch 097 loss 0.0002
# Epoch 098 loss 0.0003
